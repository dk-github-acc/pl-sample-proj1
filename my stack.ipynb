# %%
list=[]
top= -1

def push(top):
    
    x=int(input('enter an element:'))
    list.append(x)
    top=top + 1
    print(list)
    return top
  
def popele():
    
    if list==[] :
        print('stack empty \nelements cannot be popped further\n')
        
    else :
        list.pop(top)
        top=top-1
        print(list)
    
def prinstck():
    
    print('The stack is\n')
    print(list)

def main():
    
    for i in range(0,100):
        print(' menu:\n 1) Push an element \n 2)Pop an element \n 3)Print the stack\n4)Exit\n ')
        ch=int(input('enter your choice: '))
        if ch ==1:
            push(top)
            
            
        elif ch == 2:
            n=int(input('How many element u want to delete:'))
            for i in range(1,n) :
                popele()
                
        elif ch == 3:
            prinstck()
        
        else :
            break
            
if __name__=='__main__':    
    main()
# Out:
#  menu:
#  1) Push an element
#  2)Pop an element
#  3)Print the stack
# 4)Exit
#
# enter your choice: 1
# enter an element:12
# [12]
#  menu:
#  1) Push an element
#  2)Pop an element
#  3)Print the stack
# 4)Exit
#
# enter your choice: 1
# enter an element:100
# [12, 100]
#  menu:
#  1) Push an element
#  2)Pop an element
#  3)Print the stack
# 4)Exit
#
# enter your choice: 2
# How many element u want to delete:1
#  menu:
#  1) Push an element
#  2)Pop an element
#  3)Print the stack
# 4)Exit
#
# enter your choice: 1
# enter an element:0
# [12, 100, 0]
#  menu:
#  1) Push an element
#  2)Pop an element
#  3)Print the stack
# 4)Exit
